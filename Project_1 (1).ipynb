# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df.head(5)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# 1                      6.3                         15
# 2                     11.1                          8
# 3                        s                          s
# 4                        s                          s
#
#   Percent Scoring 65 or Above Number Scoring 80 or Above  \
# 0                           s                          s
# 1                        93.8                          7
# 2                        88.9                          2
# 3                           s                          s
# 4                           s                          s
#
#   Percent Scoring 80 or Above Number Scoring CR Percent Scoring CR
# 0                           s                na                 na
# 1                        43.8                na                 na
# 2                        22.2                na                 na
# 3                           s                na                 na
# 4                           s                na                 na

# %%
#taking a look at the dataset and trying to figure out what the dataset looks like before I start.

print('Shape (rows, columns):', df.shape)

print('\nColumn names:')
print(df.columns)

print('\nData types and non-null counts:')
df.info()

print('\nSummary statistics (numeric columns):')
df.describe()
# Out:
# Shape (rows, columns): (212331, 15)
#
# Column names:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
#  12  Percent Scoring 80 or Above  212331 non-null  object
#  13  Number Scoring CR            212331 non-null  object
#  14  Percent Scoring CR           212331 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 24.3+ MB
#
# Summary statistics (numeric columns):
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.sample(5,)
# Out:
#        School DBN                                       School Name  \
# 104128     02M308                      Lower Manhattan Arts Academy
# 148746     02M600             The High School of Fashion Industries
# 159652     08X558                        Westchester Square Academy
# 106097     02M520  Murry Bergtraum High School for Business Careers
# 61672      04M372                     Esperanza Preparatory Academy
#
#             School Level                 Regents Exam  Year  Total Tested  \
# 104128       High school          Common Core English  2016            62
# 148746       High school         Common Core Geometry  2017            30
# 159652       High school         Common Core Geometry  2017            40
# 106097       High school         Common Core Geometry  2017            28
# 61672   Secondary School  U.S. History and Government  2017            28
#
#        Mean Score Number Scoring Below 65 Percent Scoring Below 65  \
# 104128         81                       2                      3.2
# 148746       72.4                       7                     23.3
# 159652       62.2                      22                       55
# 106097       49.6                      25                     89.3
# 61672        76.9                       2                      7.1
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 104128                         60                        96.8
# 148746                         23                        76.7
# 159652                         18                          45
# 106097                          3                        10.7
# 61672                          26                        92.9
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 104128                         39                        62.9
# 148746                          7                        23.3
# 159652                          1                         2.5
# 106097                          0                           0
# 61672                          14                          50
#
#        Number Scoring CR Percent Scoring CR
# 104128                42               67.7
# 148746                20               66.7
# 159652                10                 25
# 106097                 1                3.6
# 61672                 na                 na

# %%
df.describe(include='all')
# Out:
#        School DBN                                        School Name  \
# count      212331                                             212331
# unique       1018                                               1012
# top        26Q430  New Visions Charter High School for Advanced Math
# freq          490                                               1337
# mean          NaN                                                NaN
# std           NaN                                                NaN
# min           NaN                                                NaN
# 25%           NaN                                                NaN
# 50%           NaN                                                NaN
# 75%           NaN                                                NaN
# max           NaN                                                NaN
#
#        School Level         Regents Exam           Year   Total Tested  \
# count        212331               212321  212331.000000  212331.000000
# unique            6                   14            NaN            NaN
# top     High school  Common Core Algebra            NaN            NaN
# freq         151160                29254            NaN            NaN
# mean            NaN                  NaN    2015.956069      49.364200
# std             NaN                  NaN       0.799726      93.023576
# min             NaN                  NaN    2015.000000       1.000000
# 25%             NaN                  NaN    2015.000000       5.000000
# 50%             NaN                  NaN    2016.000000      20.000000
# 75%             NaN                  NaN    2017.000000      57.000000
# max             NaN                  NaN    2017.000000    1729.000000
#
#        Mean Score Number Scoring Below 65 Percent Scoring Below 65  \
# count      212331                  212331                   212331
# unique        748                     446                      992
# top             s                       s                        s
# freq        75222                   75222                    75222
# mean          NaN                     NaN                      NaN
# std           NaN                     NaN                      NaN
# min           NaN                     NaN                      NaN
# 25%           NaN                     NaN                      NaN
# 50%           NaN                     NaN                      NaN
# 75%           NaN                     NaN                      NaN
# max           NaN                     NaN                      NaN
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# count                      212331                      212331
# unique                        945                         992
# top                             s                           s
# freq                        75222                       75222
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# count                      212331                      212331
# unique                        744                        1000
# top                             s                           s
# freq                        75222                       75222
# mean                          NaN                         NaN
# std                           NaN                         NaN
# min                           NaN                         NaN
# 25%                           NaN                         NaN
# 50%                           NaN                         NaN
# 75%                           NaN                         NaN
# max                           NaN                         NaN
#
#        Number Scoring CR Percent Scoring CR
# count             212331             212331
# unique               707                999
# top                   na                 na
# freq              142680             142680
# mean                 NaN                NaN
# std                  NaN                NaN
# min                  NaN                NaN
# 25%                  NaN                NaN
# 50%                  NaN                NaN
# 75%                  NaN                NaN
# max                  NaN                NaN

# %%
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(' ', '_')
      .str.replace('-', '_')
)
df.columns

#df['regents_exam'].unique()[:20]

#print(df['regents_exam'].unique()[:20])

#What is the point of the lines below?:
#df['mean_score'] = df['mean_score'].replace('N/A', np.nan)
#df['mean_score'] = pd.to_numeric(df['mean_score'], errors='coerce')

#Replace blank with a value
#then convert into a category
# Out:
# Index(['school_dbn', 'school_name', 'school_level', 'regents_exam', 'year',
#        'total_tested', 'mean_score', 'number_scoring_below_65',
#        'percent_scoring_below_65', 'number_scoring_65_or_above',
#        'percent_scoring_65_or_above', 'number_scoring_80_or_above',
#        'percent_scoring_80_or_above', 'number_scoring_cr',
#        'percent_scoring_cr'],
#       dtype='object')

# %%
#changing datatypes

#DBN, School Name, School level, Regents Exam (change to category)

df['school_dbn'] = df['school_dbn'].astype('category')

df['school_name'] = df['school_name'].astype('category')

df['school_level'] = df['school_level'].astype('category')

df['regents_exam'] = df['regents_exam'].astype('category')

df.info()

#everything else is a float.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   school_dbn                   212331 non-null  category
#  1   school_name                  212331 non-null  category
#  2   school_level                 212331 non-null  category
#  3   regents_exam                 212321 non-null  category
#  4   year                         212331 non-null  int64
#  5   total_tested                 212331 non-null  int64
#  6   mean_score                   212331 non-null  object
#  7   number_scoring_below_65      212331 non-null  object
#  8   percent_scoring_below_65     212331 non-null  object
#  9   number_scoring_65_or_above   212331 non-null  object
#  10  percent_scoring_65_or_above  212331 non-null  object
#  11  number_scoring_80_or_above   212331 non-null  object
#  12  percent_scoring_80_or_above  212331 non-null  object
#  13  number_scoring_cr            212331 non-null  object
#  14  percent_scoring_cr           212331 non-null  object
# dtypes: category(4), int64(2), object(9)
# memory usage: 19.1+ MB

# %%
df['mean_score'] = pd.to_numeric(df['mean_score'], errors='coerce')
df['number_scoring_below_65'] = pd.to_numeric(df['number_scoring_below_65'], errors='coerce')
df['percent_scoring_below_65'] = pd.to_numeric(df['percent_scoring_below_65'], errors='coerce')
df['number_scoring_65_or_above'] = pd.to_numeric(df['number_scoring_65_or_above'], errors='coerce')
df['percent_scoring_65_or_above'] = pd.to_numeric(df['percent_scoring_65_or_above'], errors='coerce')
df['number_scoring_80_or_above'] = pd.to_numeric(df['number_scoring_80_or_above'], errors='coerce')
df['percent_scoring_80_or_above'] = pd.to_numeric(df['percent_scoring_80_or_above'], errors='coerce')
df['number_scoring_cr'] = pd.to_numeric(df['number_scoring_cr'], errors='coerce')
df['percent_scoring_cr'] = pd.to_numeric(df['percent_scoring_cr'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   school_dbn                   212331 non-null  category
#  1   school_name                  212331 non-null  category
#  2   school_level                 212331 non-null  category
#  3   regents_exam                 212321 non-null  category
#  4   year                         212331 non-null  int64
#  5   total_tested                 212331 non-null  int64
#  6   mean_score                   137109 non-null  float64
#  7   number_scoring_below_65      137109 non-null  float64
#  8   percent_scoring_below_65     137109 non-null  float64
#  9   number_scoring_65_or_above   137109 non-null  float64
#  10  percent_scoring_65_or_above  137109 non-null  float64
#  11  number_scoring_80_or_above   137109 non-null  float64
#  12  percent_scoring_80_or_above  137109 non-null  float64
#  13  number_scoring_cr            69651 non-null   float64
#  14  percent_scoring_cr           69651 non-null   float64
# dtypes: category(4), float64(9), int64(2)
# memory usage: 19.1 MB

# %%
#I am finding the missing data and how many unique values each column has.

print('Missing values per column:')
print(df.isna().sum())

print('\nPercentage of missing values per column:')
print((df.isna().mean() * 100).round(2))

print('\nNumber of unique values per column:')
print(df.nunique())
# Out:
# Missing values per column:
# school_dbn                          0
# school_name                         0
# school_level                        0
# regents_exam                       10
# year                                0
# total_tested                        0
# mean_score                      75222
# number_scoring_below_65         75222
# percent_scoring_below_65        75222
# number_scoring_65_or_above      75222
# percent_scoring_65_or_above     75222
# number_scoring_80_or_above      75222
# percent_scoring_80_or_above     75222
# number_scoring_cr              142680
# percent_scoring_cr             142680
# dtype: int64
#
# Percentage of missing values per column:
# school_dbn                      0.00
# school_name                     0.00
# school_level                    0.00
# regents_exam                    0.00
# year                            0.00
# total_tested                    0.00
# mean_score                     35.43
# number_scoring_below_65        35.43
# percent_scoring_below_65       35.43
# number_scoring_65_or_above     35.43
# percent_scoring_65_or_above    35.43
# number_scoring_80_or_above     35.43
# percent_scoring_80_or_above    35.43
# number_scoring_cr              67.20
# percent_scoring_cr             67.20
# dtype: float64
#
# Number of unique values per column:
# school_dbn                     1018
# school_name                    1012
# school_level                      6
# regents_exam                     14
# year                              3
# total_tested                   1126
# mean_score                      747
# number_scoring_below_65         445
# percent_scoring_below_65        991
# number_scoring_65_or_above      944
# percent_scoring_65_or_above     991
# number_scoring_80_or_above      743
# percent_scoring_80_or_above     999
# number_scoring_cr               706
# percent_scoring_cr              998
# dtype: int64

# %%
#I am imputing missing numeric values with the median, which is robust to outliers.

mean_score_median = df['mean_score'].median()
df['mean_score'] = df['mean_score'].fillna(mean_score_median)

number_scoring_below_65_median = df['number_scoring_below_65'].median()
df['number_scoring_below_65'] = df['number_scoring_below_65'].fillna(number_scoring_below_65_median)

percent_scoring_below_65_median = df['percent_scoring_below_65'].median()
df['percent_scoring_below_65'] = df['percent_scoring_below_65'].fillna(percent_scoring_below_65_median)

number_scoring_65_or_above_median = df['number_scoring_65_or_above'].median()
df['number_scoring_65_or_above'] = df['number_scoring_65_or_above'].fillna(number_scoring_65_or_above_median)

percent_scoring_65_or_above_median = df['percent_scoring_65_or_above'].median()
df['percent_scoring_65_or_above'] = df['percent_scoring_65_or_above'].fillna(percent_scoring_65_or_above_median)

number_scoring_80_or_above_median = df['number_scoring_80_or_above'].median()
df['number_scoring_80_or_above'] = df['number_scoring_80_or_above'].fillna(number_scoring_80_or_above_median)

percent_scoring_80_or_above_median = df['percent_scoring_80_or_above'].median()
df['percent_scoring_80_or_above'] = df['percent_scoring_80_or_above'].fillna(percent_scoring_80_or_above_median)

number_scoring_cr_median = df['number_scoring_cr'].median()
df['number_scoring_cr'] = df['number_scoring_cr'].fillna(number_scoring_cr_median)

percent_scoring_cr_median = df['percent_scoring_cr'].median()
df['percent_scoring_cr'] = df['percent_scoring_cr'].fillna(percent_scoring_cr_median)

df.isna().sum()
# Out:
# school_dbn                      0
# school_name                     0
# school_level                    0
# regents_exam                   10
# year                            0
# total_tested                    0
# mean_score                      0
# number_scoring_below_65         0
# percent_scoring_below_65        0
# number_scoring_65_or_above      0
# percent_scoring_65_or_above     0
# number_scoring_80_or_above      0
# percent_scoring_80_or_above     0
# number_scoring_cr               0
# percent_scoring_cr              0
# dtype: int64

# %%
print(df['regents_exam'].unique())
# Out:
# ['Common Core Algebra', 'Living Environment', 'Common Core English', 'Algebra2/Trigonometry', 'Common Core Algebra2', ..., 'Physical Settings/Chemistry', 'Physical Settings/Earth Science', 'U.S. History and Government', 'Physical Settings/Physics', NaN]
# Length: 15
# Categories (14, object): ['Algebra2/Trigonometry', 'Common Core Algebra', 'Common Core Algebra2',
#                           'Common Core English', ..., 'Physical Settings/Chemistry',
#                           'Physical Settings/Earth Science', 'Physical Settings/Physics',
#                           'U.S. History and Government']

# %%
#choosing a school
#P.S. 034 Franklin D. Roosevelt

# %%
#FDR=pd.DataFrame()

FDR = df[df['school_name'] == 'P.S. 034 Franklin D. Roosevelt'].copy()

FDR.describe()

FDR.head()
# Out:
#       school_dbn                     school_name school_level  \
# 0         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2         01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               regents_exam  year  total_tested  mean_score  \
# 0      Common Core Algebra  2017             4        65.4
# 1       Living Environment  2015            16        77.9
# 2       Living Environment  2016             9        74.0
# 19478  Common Core Algebra  2017             3        65.4
# 19479  Common Core Algebra  2017             1        65.4
#
#        number_scoring_below_65  percent_scoring_below_65  \
# 0                         13.0                      40.2
# 1                          1.0                       6.3
# 2                          1.0                      11.1
# 19478                     13.0                      40.2
# 19479                     13.0                      40.2
#
#        number_scoring_65_or_above  percent_scoring_65_or_above  \
# 0                            21.0                         59.8
# 1                            15.0                         93.8
# 2                             8.0                         88.9
# 19478                        21.0                         59.8
# 19479                        21.0                         59.8
#
#        number_scoring_80_or_above  percent_scoring_80_or_above  \
# 0                             5.0                         12.5
# 1                             7.0                         43.8
# 2                             2.0                         22.2
# 19478                         5.0                         12.5
# 19479                         5.0                         12.5
#
#        number_scoring_cr  percent_scoring_cr
# 0                    9.0                29.0
# 1                    9.0                29.0
# 2                    9.0                29.0
# 19478                9.0                29.0
# 19479                9.0                29.0

# %%
#categorical_cols = [
    #'school_name', 'school_level', 'regents_exam', 'year',
    #'total_tested', 'mean_score	', 'number_scoring_below_65', 'percent_scoring_below_65', 'number_scoring_65_or_above','percent_scoring_65_or_above',
   # 'number_scoring_80_or_above', 'percent_scoring_80_or_above','number_scoring_cr', 'percent_scoring_cr'

#]

#for col in categorical_cols:
   # df[col] = df[col].astype('category')

#df[categorical_cols].dtypes

# %%
#Created the category distribution for all categories

def show_category_distribution(col_name):
    counts = df[col_name].value_counts()
    percents = df[col_name].value_counts(normalize=True) * 100
    display(pd.DataFrame({'count': counts, 'percent': percents.round(2)}))

for col in ['school_name','school_level', 'regents_exam','year','total_tested','mean_score','number_scoring_below_65', 'percent_scoring_below_65', 'number_scoring_65_or_above', 'percent_scoring_65_or_above', 'number_scoring_80_or_above',
'percent_scoring_80_or_above','number_scoring_cr', 'percent_scoring_cr']:

    print(f'--- {col} ---')

    show_category_distribution(col)

    print()
# Out:
# --- school_name ---
#                                                     count  percent
# school_name
# New Visions Charter High School for Advanced Math    1337     0.63
# New Visions Charter High School for the Humanities   1031     0.49
# James Madison High School                             490     0.23
# Francis Lewis High School                             490     0.23
# Long Island City High School                          489     0.23
# ...                                                   ...      ...
# Success Academy Charter School - Harlem 3               5     0.00
# P.S. 202 Ernest S. Jenkyns                              5     0.00
# Explore Excel Charter School                            5     0.00
# Community Math & Science Prep                           5     0.00
# Academy for New Americans                               5     0.00
#
# [1012 rows x 2 columns]
# --- school_level ---
#                                   count  percent
# school_level
# High school                      151160    71.19
# Secondary School                  30252    14.25
# Junior High-Intermediate-Middle   15742     7.41
# K-12 all grades                    8294     3.91
# K-8                                6858     3.23
# Elementary                           25     0.01
# --- regents_exam ---
#                                  count  percent
# regents_exam
# Common Core Algebra              29254    13.78
# Living Environment               25539    12.03
# U.S. History and Government      20426     9.62
# Common Core English              19878     9.36
# Global History and Geography     19192     9.04
# Physical Settings/Earth Science  15971     7.52
# Common Core Geometry             15267     7.19
# Physical Settings/Chemistry      11670     5.50
# English                          11091     5.22
# Integrated Algebra               11022     5.19
# Algebra2/Trigonometry            10788     5.08
# Geometry                          8509     4.01
# Common Core Algebra2              7915     3.73
# Physical Settings/Physics         5799     2.73
# --- year ---
#       count  percent
# year
# 2016  76123    35.85
# 2015  72768    34.27
# 2017  63440    29.88
# --- total_tested ---
#               count  percent
# total_tested
# 1             22010    10.37
# 2             12750     6.00
# 3              9168     4.32
# 4              7264     3.42
# 5              6263     2.95
# ...             ...      ...
# 940               1     0.00
# 964               1     0.00
# 915               1     0.00
# 679               1     0.00
# 951               1     0.00
#
# [1126 rows x 2 columns]
# --- mean_score ---
#             count  percent
# mean_score
# 65.4        75747    35.67
# 64.3          555     0.26
# 63.3          555     0.26
# 62.3          552     0.26
# 63.8          550     0.26
# ...           ...      ...
# 97.8            1     0.00
# 98.0            1     0.00
# 98.7            1     0.00
# 15.7            1     0.00
# 25.0            1     0.00
#
# [747 rows x 2 columns]
# --- number_scoring_below_65 ---
#                          count  percent
# number_scoring_below_65
# 13.0                     78341    36.90
# 0.0                      10252     4.83
# 1.0                       5978     2.82
# 6.0                       5493     2.59
# 5.0                       5386     2.54
# ...                        ...      ...
# 361.0                        1     0.00
# 483.0                        1     0.00
# 453.0                        1     0.00
# 366.0                        1     0.00
# 371.0                        1     0.00
#
# [445 rows x 2 columns]
# --- percent_scoring_below_65 ---
#                           count  percent
# percent_scoring_below_65
# 40.2                      75296    35.46
# 0.0                       10252     4.83
# 100.0                      3330     1.57
# 50.0                       2889     1.36
# 66.7                       1974     0.93
# ...                         ...      ...
# 91.6                          2     0.00
# 95.4                          2     0.00
# 98.8                          2     0.00
# 66.6                          1     0.00
# 94.8                          1     0.00
#
# [991 rows x 2 columns]
# --- number_scoring_65_or_above ---
#                             count  percent
# number_scoring_65_or_above
# 21.0                        76943    36.24
# 6.0                          4684     2.21
# 4.0                          4459     2.10
# 3.0                          4343     2.05
# 5.0                          4332     2.04
# ...                           ...      ...
# 1076.0                          1     0.00
# 825.0                           1     0.00
# 807.0                           1     0.00
# 786.0                           1     0.00
# 813.0                           1     0.00
#
# [944 rows x 2 columns]
# --- percent_scoring_65_or_above ---
#                              count  percent
# percent_scoring_65_or_above
# 59.8                         75296    35.46
# 100.0                        10252     4.83
# 0.0                           3330     1.57
# 50.0                          2889     1.36
# 33.3                          1974     0.93
# ...                            ...      ...
# 1.0                              2     0.00
# 25.1                             2     0.00
# 4.6                              2     0.00
# 5.2                              1     0.00
# 33.4                             1     0.00
#
# [991 rows x 2 columns]
# --- number_scoring_80_or_above ---
#                             count  percent
# number_scoring_80_or_above
# 5.0                         80102    37.73
# 0.0                         29996    14.13
# 1.0                         14522     6.84
# 2.0                          9656     4.55
# 3.0                          7434     3.50
# ...                           ...      ...
# 778.0                           1     0.00
# 546.0                           1     0.00
# 736.0                           1     0.00
# 744.0                           1     0.00
# 500.0                           1     0.00
#
# [743 rows x 2 columns]
# --- percent_scoring_80_or_above ---
#                              count  percent
# percent_scoring_80_or_above
# 12.5                         76453    36.01
# 0.0                          29996    14.13
# 100.0                         1524     0.72
# 16.7                          1484     0.70
# 14.3                          1324     0.62
# ...                            ...      ...
# 50.1                             3     0.00
# 83.4                             2     0.00
# 49.9                             2     0.00
# 66.6                             1     0.00
# 0.2                              1     0.00
#
# [999 rows x 2 columns]
# --- number_scoring_cr ---
#                     count  percent
# number_scoring_cr
# 9.0                144258    67.94
# 0.0                  9076     4.27
# 1.0                  5640     2.66
# 2.0                  4152     1.96
# 3.0                  3363     1.58
# ...                   ...      ...
# 523.0                   1     0.00
# 1295.0                  1     0.00
# 1327.0                  1     0.00
# 1306.0                  1     0.00
# 1365.0                  1     0.00
#
# [706 rows x 2 columns]
# --- percent_scoring_cr ---
#                      count  percent
# percent_scoring_cr
# 29.0                142728    67.22
# 0.0                   9076     4.27
# 100.0                 2799     1.32
# 50.0                  1000     0.47
# 33.3                   897     0.42
# ...                    ...      ...
# 91.6                     3     0.00
# 66.6                     2     0.00
# 33.4                     2     0.00
# 49.9                     2     0.00
# 0.4                      1     0.00
#
# [998 rows x 2 columns]

# %%
#graphs of the mean score, the grades below 65, and the percent below 65 to analyze



fig, axes = plt.subplots(1, 3, figsize=(18, 4))

sns.histplot(FDR['mean_score'], bins=30, kde=True, ax=axes[0])
axes[0].set_title('Mean Score')

sns.histplot(FDR['number_scoring_below_65'], bins=30, kde=True, ax=axes[1])
axes[1].set_title('Grades Below 65')

sns.histplot(FDR['percent_scoring_below_65'], bins=30, kde=True, ax=axes[2])
axes[2].set_title('Percent Below 65')

plt.tight_layout()
plt.show()

# %%
#graphs of the mean score, the grades below 65, and the percent below 65

fig, axes = plt.subplots(1, 3, figsize=(18, 10))

sns.boxplot(y=FDR['mean_score'], ax=axes[0])
axes[0].set_title('Mean Score')

sns.boxplot(y=FDR['number_scoring_below_65'], ax=axes[1])
axes[1].set_title('Grades Below 65')

sns.boxplot(y=FDR['percent_scoring_below_65'], ax=axes[2])
axes[2].set_title('Percent Below 65')


plt.tight_layout()
plt.show()

# %%
#graphs of the regents exams and the years tested

plt.figure(figsize=(6, 4))
sns.countplot(x='regents_exam', data=FDR)
plt.title('Regents Exam')
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(x='year', data=FDR)
plt.title('Years Tested')
plt.xticks(rotation=30)
plt.show()

plt.figure(figsize=(8, 4))
sns.countplot(x='number_scoring_below_65', data=FDR)
plt.title('Number Scoring')
plt.xticks(rotation=30)
plt.show()

plt.figure(figsize=(4, 4))
sns.countplot(x='percent_scoring_below_65', data=FDR)
plt.title('Percent Scoring')
plt.show()

# %%
#In conclusion, In 2017 less students tested and most students graded below 65% at the school district level.
